# %%
import pandas as pd
import matplotlib.pyplot as plt

Dat = pd.read_csv('data/billionaires.csv')
print(Dat.shape)

filt = Dat[Dat['wealth.how.inherited']=='not inherited']
print(min(filt['demographics.age']))
#print(filt.shape)
print(filt.describe)

#print(filt['wealth.how.inherited'].value_counts())

#plt.hist(filt['demographics.age'])
# Out:
# (2614, 22)
# -42
# <bound method NDFrame.describe of                 name  rank  year  company.founded  \
# 0         Bill Gates     1  1996             1975
# 1         Bill Gates     1  2001             1975
# 2         Bill Gates     1  2014             1975
# 3     Warren Buffett     2  1996             1962
# 4     Warren Buffett     2  2001             1962
# ...              ...   ...   ...              ...
# 2609     Wu Chung-Yi  1565  2014             1991
# 2610        Wu Xiong  1565  2014             1999
# 2611       Yang Keng  1565  2014                0
# 2612   Zdenek Bakala  1565  2014             1994
# 2613     Zhu Wenchen  1565  2014             1999
#
#                          company.name company.relationship  \
# 0                           Microsoft              founder
# 1                           Microsoft              founder
# 2                           Microsoft              founder
# 3                  Berkshire Hathaway              founder
# ...
